# %%
# !where python
# Out:
# d:\Programaci�n\AiMailRol\.venv\Scripts\python.exe
# C:\Users\Darkcon\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
import sys
sys.path.append("d:/Programación/AiMailRol")  # Agregar el directorio raíz al PYTHONPATH


from IPython.display import Image, display
from ia.langgraph.graphs.processing_graph import ProcessingGraph

# Crear una instancia del grafo
processing_graph = ProcessingGraph()

# Obtener el grafo compilado
compiled_graph = processing_graph.graph

# Visualizar el grafo
display(Image(compiled_graph.get_graph().draw_mermaid_png()))
